# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python-practice/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#swap without using third variable
a = 10
b = 20
a = a+b
b =a-b
a = a-b

print(a, b)
# Out:
# 20 10

# %%
# largest three numbers
a,b,c = 15,65,25
d = a
if b > d:
  d  = b
if c > d:
  d = c

print("largest number is :",d)
# Out:
# largest number is : 65

# %%
#revers a string
stg = input("enter a name to reverse : ")
print(stg [::-1])
# Out:
# enter a name to reverse : arjun
# nujra

# %%
# palindrome
s = input("Enter to check whwtre it is palindrome or not ")
if s == s[::-1]:
  print("it is palindrome ")
else :
  print("it is not palindrome ")
# Out:
# Enter to check whwtre it is palindrome or not banab
# it is palindrome
