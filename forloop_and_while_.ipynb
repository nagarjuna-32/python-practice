# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python-practice/blob/main/forloop_and_while_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [1, 2, 3, 4, 5]
squares = []

for num in numbers:
    squares.append(num ** 2)

print(f"Original: {numbers}")
print(f"Squares: {squares}")
# Out:
# Original: [1, 2, 3, 4, 5]
# Squares: [1, 4, 9, 16, 25]

# %%
secret_pass = "python123"
user_input = ""

while user_input != secret_pass:
    user_input = input("Enter the password: ")
    if user_input != secret_pass:
        print("Access Denied. Try again.")

print("Access Granted!")
# Out:
# Enter the password: arjun
# Access Denied. Try again.
# Enter the password: python123
# Access Granted!
