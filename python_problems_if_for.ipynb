# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python-practice/blob/main/python_problems_if_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#positive and negativui zero

num = int(input("enter a number to check positive, negativi or xero:"))

if num <0 :
  print("megative number ")
elif num >0:
  print("positive number")
else:
  print("zero")
# Out:
# enter a number to check positive or xero:0
# zero

# %%
year = int(input("enter a year to check leap year or not:"))

if (year %400==0):
  print("its a leap year ")
else:
  print("its not a leap year")
# Out:
# enter a year to check leap year or not:34543
# its not a leap year

# %%
num =int(input("enter the table "))

for i  in range (1,11):
  print(num ,"X" ,i, "=",num*i )
# Out:
# enter the table 10
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100

# %%
lst = list(map(int,input("enter a word or number to reverse").split()))
print(lst[::-1])
# Out:
# enter a word or number to reverse1 2 3 4 5 67 8 9 5 4 263 56
# [56, 263, 4, 5, 9, 8, 67, 5, 4, 3, 2, 1]

# %%
# Out:
# 5
