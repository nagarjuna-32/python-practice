# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python-practice/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
has_ticket = True
age = 15

if has_ticket:
    if age >= 18:
        print("Welcome to the movie!")
    else:
        print("You need a guardian to enter.")
else:
    print("Please buy a ticket first.")
