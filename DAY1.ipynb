# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python-practice/blob/main/DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
Name = "Arjun"
age = 20
game = "volleyball"
print(Name,age,game)
# Out:
# Arjun 20 volleyball

# %%
name = input("Enter your name: ")
age = input("enter your age :")
game = input ("Enter your game ")
print("name is ",name)
print("age is ",age)
print("game is ",game)
# Out:
# Enter your name: NAGARJUNA
# enter your age :20
# Enter your game VOLLEYBALL
# name is  NAGARJUNA
# age is  20
# game is  VOLLEYBALL

# %%
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))

print("Sum =", x + y)
print("Difference =", x - y)
print("Product =", x * y)
print("Divide =", x / y)
# Out:
# Enter first number: 56
# Enter second number: 35
# Sum = 91
# Difference = 21
# Product = 1960
# Divide = 1.6

# %%
n = int(input("Enter number: "))

if n % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter number: 6
# Even number
